# %%
# imports
import os
import io
import tokenize
import numpy as np
import pandas as pd

import re

# %%
# paths
# zeppelin_folder = '/home/ourownstory/Documents/SOL/data/Zeppelin/Zeppelin/crowdsale/'
zeppelin_joined = '/home/ourownstory/Documents/SOL/derived/test/joined/Zeppelin/Zeppelin/'
# os.listdir(zeppelin_folder)
os.listdir(zeppelin_joined)
crowdsale_joined = 'crowdsale/Crowdsale.sol'
# BasicToken.sol     CappedToken.sol    ERC20Basic.sol  MintableToken.sol  SafeERC20.sol      TokenTimelock.sol
# BurnableToken.sol  DetailedERC20.sol  ERC20.sol       PausableToken.sol  StandardToken.sol  TokenVesting.sol

# %%
# src reader from dat_wrangling notebook
# NOTE: modified to return list

# strips pragma statements and comments
def read_src_nocomments(file_name, return_only_comments=False):
    with open(file_name, 'r') as f:
        src_list = []
        comments_list = []
        for line in f.readlines():
            # skip pragma
            if re.match('pragma solidity .*;', line.strip()):
                continue
            # single or multiline comments
            if re.match('/', line.strip()) or re.match('\*', line.strip()):
                comments_list.append(line)
                continue
            # inline comments
            if re.search('//', line):
                inline_comment = re.findall('[\s]*//.*\n', line)
                comments_list.extend(inline_comment)
                line = re.sub('[\s]*//.*\n', '\n', line)
                continue
                
            # add current src line
            src_list.append(line)
        
        if return_only_comments:
            return comments_list
        else:
            return src_list

def remove_import_lines(src):
#     print src
    regex = "import .*;"
    src = [x for x in src if not re.match(regex, x)]
#     print src
    return src

# %%
# read in as txt
raw_lines = []
with open(zeppelin_joined+crowdsale_joined, 'r') as file:
    for line in file:
        raw_lines.append(line)
        
# read stripped src
# raw_lines = read_src_nocomments(file_name=zeppelin_joined+crowdsale_joined)
# raw_lines = remove_import_lines(raw_lines)

# %%
# raw_lines

# %%
# for raw_line in raw_lines:
#     print(raw_line.split())

# %%
# would need to use hand-crafted regex to split as wanted.
# TODO: implement if tokenize not desirable.

# %%
# approach using tokenize

# %%
tokens_dict = {
    'line': [],
    'line_se': [],
    'type': [],
    'value': [],
}
tokens_list = []
with open(zeppelin_joined+crowdsale_joined, 'r') as file:
    token_generator = tokenize.generate_tokens(file.readline)
    for type, token, (srow, scol), (erow, ecol), line in token_generator:
        tokens_dict['line'].append(srow)        
        tokens_dict['line_se'].append(((srow, scol), (erow, ecol)))    
        tokens_dict['type'].append(tokenize.tok_name[type])        
        tokens_dict['value'].append(repr(token))
        tokens_list.append([srow, tokenize.tok_name[type], repr(token)])
        
tokens = pd.DataFrame.from_dict(tokens_dict)

# %%
# tokens

# %%
# token_types, type_counts = np.unique(tokens['type'], return_counts=True)
# print(token_types,type_counts)

token_type_freq = pd.Series.value_counts(tokens.type, sort=True)
print(token_type_freq)
# Out:
# NAME         152
# OP           148
# NL            72
# NUMBER         4
# NEWLINE        1
# ENDMARKER      1
# Name: type, dtype: int64

# %%
# replace "NEWLINE" with "NL"
tokens['type'] = tokens['type'].apply(lambda x: 'NL' if x == 'NEWLINE' else x)

# %%
token_freq = pd.Series.value_counts(tokens.value, sort=True)
print(token_freq[:20])
# Out:
# '\n'             73
# ';'              32
# '('              29
# ')'              29
# 'uint256'        12
# '='              10
# ','              10
# 'public'          9
# '.'               9
# '}'               8
# '{'               8
# 'function'        7
# 'address'         7
# 'require'         6
# 'msg'             5
# 'beneficiary'     5
# '&'               4
# '0'               4
# 'value'           4
# 'bool'            4
# Name: value, dtype: int64

# %%
op_freq = pd.Series.value_counts(tokens[tokens.type == 'OP'].value, sort=True)
print(op_freq[:20])
# Out:
# ';'     32
# '('     29
# ')'     29
# '='     10
# ','     10
# '.'      9
# '}'      8
# '{'      8
# '&'      4
# '!='     3
# '>='     3
# '>'      2
# '<='     1
# Name: value, dtype: int64

# %%
name_freq = pd.Series.value_counts(tokens[tokens.type == 'NAME'].value, sort=True)
print(name_freq[:20])
# Out:
# 'uint256'        12
# 'public'          9
# 'function'        7
# 'address'         7
# 'require'         6
# 'beneficiary'     5
# 'msg'             5
# 'endTime'         4
# 'now'             4
# 'bool'            4
# 'value'           4
# 'weiAmount'       4
# '_startTime'      4
# '_wallet'         3
# 'weiRaised'       3
# 'wallet'          3
# 'rate'            3
# 'tokens'          3
# 'return'          3
# 'returns'         3
# Name: value, dtype: int64

# %%
## Next steps:

# %%
# 1. write tokenization function that receives a list of paths 
# and does the tokenization and counts for all files in paths.

# %%
# create a pandas dataframe with the filenames in our dataset

# paths
data_path =  '/home/ourownstory/Documents/SOL/derived/test/cleaned/'
out_path = '/home/ourownstory/Documents/SOL/derived/test/'


df_files_dict = {
    'root': [],
    'file_name': [],
}
for root, subdirs, df_files in os.walk(data_path):
    for file_name in df_files:
        df_files_dict['root'].append(root[len(data_path):])
        df_files_dict['file_name'].append(file_name)
df_files = pd.DataFrame.from_dict(df_files_dict)
root_list = df_files['root'].values
root_list = [root.split('/') for root in root_list]
df_files['class'] = [r.pop(0) for r in root_list]
df_files['company'] = [r.pop(0) for r in root_list]
df_files['root'] = ["/".join(r) for r in root_list]
file_name_list = df_files['file_name'].values
df_files['extension'] = [e.split('.')[-1] for e in file_name_list]

# filter all files that are not .sol
df_files = df_files[df_files.pop('extension') == 'sol']
# filter all comment-files
df_files['is_comment'] = df_files['file_name'].apply(lambda x: bool(re.match('comments_', x)))
df_files = df_files[df_files.pop('is_comment') == False]


# helper func to get file-path

def get_filename_for_row(row):
    filename = os.path.join(
        data_path, 
        row.loc['class'], 
        row.loc['company'], 
        row.loc['root'], 
        row.loc['file_name']
    )
    return filename

# %%
def tokenize_file(filename):
    tokens_dict = {
        'line': [],
        'line_se': [],
        'type': [],
        'value': [],
    }
    tokens_list = []
    with open(filename, 'r') as file:
        token_generator = tokenize.generate_tokens(file.readline)
        for type, token, (srow, scol), (erow, ecol), line in token_generator:
            tokens_dict['line'].append(srow)        
            tokens_dict['line_se'].append(((srow, scol), (erow, ecol)))    
            tokens_dict['type'].append(tokenize.tok_name[type])        
            tokens_dict['value'].append(repr(token))
            tokens_list.append([srow, tokenize.tok_name[type], repr(token)])
            
    tokens_dict['type'] = ['NL' if x == 'NEWLINE' else x for x in tokens_dict['type']]

    return tokens_dict

def tokenize_file_from_row(row):
    filename = get_filename_for_row(row)
#     print filename
    tokens_dict = tokenize_file(filename)
    row['lines'] = tokens_dict['line_se']
    row['types'] = tokens_dict['type']
    row['values'] = tokens_dict['value']
    return row

# %%
df_files = df_files.apply(tokenize_file_from_row, axis=1)
df_files
# Out:
#                                      file_name        root   class  \
# 3                         PullPayInterface.sol              notICO
# 4                               ERC20Basic.sol              notICO
# 6                               Migrations.sol              notICO
# 7                              ERC223Basic.sol              notICO
# 11                                   ERC20.sol              notICO
# 12                 ERC223ReceivingContract.sol              notICO
# 13                                SafeMath.sol              notICO
# 14                             PullPayment.sol   satelites  notICO
# 15                                 Storage.sol   satelites  notICO
# 19                                    Nutz.sol   satelites  notICO
# 21                                   Power.sol   satelites  notICO
# 23                            UpgradeEvent.sol    policies  notICO
# 24                              PowerEvent.sol    policies  notICO
# 25                   PowerEventReplacement.sol    policies  notICO
# 27                     UpgradeEventCompact.sol    policies  notICO
# 32                     ControllerInterface.sol  controller  notICO
# 34                             NutzEnabled.sol  controller  notICO
# 37                            PowerEnabled.sol  controller  notICO
# 38                          StorageEnabled.sol  controller  notICO
# 39                              Controller.sol  controller  notICO
# 40                           MarketEnabled.sol  controller  notICO
# 42                                Pausable.sol   ownership  notICO
# 45                                 Ownable.sol   ownership  notICO
# 47                              Governable.sol   ownership  notICO
# 48                              Migrations.sol              notICO
# 50    StandardMarketWithPriceLoggerFactory.sol     Markets  notICO
# 51                          StandardMarket.sol     Markets  notICO
# 54                                Campaign.sol     Markets  notICO
# 55                                  Market.sol     Markets  notICO
# 57                         CampaignFactory.sol     Markets  notICO
# ...                                        ...         ...     ...
# 986                             Migrations.sol                 ICO
# 987                            LordCoinICO.sol                 ICO
# 991                        LordCoinICOMock.sol                 ICO
# 992                              LM2Wallet.sol                 ICO
# 993                           LordCoinLock.sol                 ICO
# 995            NapoleonXCrowdsaleTokenTest.sol                 ICO
# 999                         MultiSigWallet.sol                 ICO
# 1000               NapoleonXCrowdsaleToken.sol                 ICO
# 1001                             Greenlist.sol                 ICO
# 1005                             Timelocks.sol                 ICO
# 1006                              MainSale.sol                 ICO
# 1007                            Migrations.sol                 ICO
# 1008                             FlipToken.sol                 ICO
# 1009                               PreSale.sol                 ICO
# 1014                       PreSaleExtended.sol                 ICO
# 1015                         FlipCrowdsale.sol                 ICO
# 1019                            SaleWallet.sol                 ICO
# 1020                           MiniMeToken.sol                 ICO
# 1022                                   ANT.sol                 ICO
# 1025                        MultisigWallet.sol                 ICO
# 1027                         ANPlaceholder.sol                 ICO
# 1028          MiniMeIrrevocableVestedToken.sol                 ICO
# 1029                       AragonTokenSale.sol                 ICO
# 1030                            Migrations.sol        misc     ICO
# 1032                            Controlled.sol   interface     ICO
# 1035                            Controller.sol   interface     ICO
# 1036                ApproveAndCallReceiver.sol   interface     ICO
# 1038                        BitDegreeToken.sol                 ICO
# 1039                    BitDegreeCrowdsale.sol                 ICO
# 1041                            Migrations.sol                 ICO
#
#             company                                              lines  \
# 3        AceBusters  [((1, 0), (1, 1)), ((2, 0), (2, 8)), ((2, 9), ...
# 4        AceBusters  [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 6        AceBusters  [((1, 0), (1, 1)), ((2, 0), (2, 8)), ((2, 9), ...
# 7        AceBusters  [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 11       AceBusters  [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 12       AceBusters  [((1, 0), (1, 1)), ((2, 1), (2, 2)), ((3, 0), ...
# 13       AceBusters  [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 14       AceBusters  [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 15       AceBusters  [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 19       AceBusters  [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 21       AceBusters  [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 23       AceBusters  [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 24       AceBusters  [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 25       AceBusters  [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 27       AceBusters  [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 32       AceBusters  [((1, 0), (1, 1)), ((2, 0), (2, 8)), ((2, 9), ...
# 34       AceBusters  [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 37       AceBusters  [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 38       AceBusters  [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 39       AceBusters  [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 40       AceBusters  [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 42       AceBusters  [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 45       AceBusters  [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 47       AceBusters  [((1, 0), (1, 1)), ((2, 0), (2, 8)), ((2, 9), ...
# 48    GnosisMarkets  [((1, 0), (1, 1)), ((2, 0), (2, 8)), ((2, 9), ...
# 50    GnosisMarkets  [((1, 0), (1, 6)), ((1, 7), (1, 53)), ((1, 53)...
# 51    GnosisMarkets  [((1, 0), (1, 6)), ((1, 7), (1, 30)), ((1, 30)...
# 54    GnosisMarkets  [((1, 0), (1, 6)), ((1, 7), (1, 28)), ((1, 28)...
# 55    GnosisMarkets  [((1, 0), (1, 6)), ((1, 7), (1, 28)), ((1, 28)...
# 57    GnosisMarkets  [((1, 0), (1, 6)), ((1, 7), (1, 32)), ((1, 32)...
# ...             ...                                                ...
# 986      LordMancer  [((1, 0), (1, 1)), ((2, 0), (2, 8)), ((2, 9), ...
# 987      LordMancer  [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 991      LordMancer  [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 992      LordMancer  [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 993      LordMancer  [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 995       NapoleonX  [((1, 0), (1, 8)), ((1, 9), (1, 17)), ((1, 18)...
# 999       NapoleonX  [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 1000      NapoleonX  [((1, 0), (1, 8)), ((1, 9), (1, 17)), ((1, 18)...
# 1001      NapoleonX  [((1, 0), (1, 1)), ((2, 0), (2, 8)), ((2, 9), ...
# 1005       Gameflip  [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 1006       Gameflip  [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 1007       Gameflip  [((1, 0), (1, 1)), ((2, 0), (2, 8)), ((2, 9), ...
# 1008       Gameflip  [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 1009       Gameflip  [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 1014       Gameflip  [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 1015       Gameflip  [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 1019         Aragon  [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 1020         Aragon  [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 1022         Aragon  [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 1025         Aragon  [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 1027         Aragon  [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 1028         Aragon  [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 1029         Aragon  [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 1030         Aragon  [((1, 0), (1, 1)), ((2, 0), (2, 8)), ((2, 9), ...
# 1032         Aragon  [((1, 0), (1, 1)), ((2, 0), (2, 4)), ((2, 4), ...
# 1035         Aragon  [((1, 0), (1, 1)), ((2, 0), (2, 4)), ((2, 4), ...
# 1036         Aragon  [((1, 0), (1, 1)), ((2, 0), (2, 4)), ((2, 4), ...
# 1038      BitDegree  [((1, 0), (1, 6)), ((1, 7), (1, 15)), ((1, 15)...
# 1039      BitDegree  [((1, 0), (1, 1)), ((2, 0), (2, 7)), ((2, 8), ...
# 1041      BitDegree  [((1, 0), (1, 1)), ((2, 0), (2, 8)), ((2, 9), ...
#
#                                                   types  \
# 3     [NL, NAME, NAME, OP, NL, NAME, NAME, OP, NAME,...
# 4     [NL, NL, NAME, NAME, OP, NL, NAME, NAME, OP, O...
# 6     [NL, NAME, NAME, OP, NL, NAME, NAME, NAME, OP,...
# 7     [NL, NAME, STRING, OP, NEWLINE, NL, NAME, NAME...
# 11    [NL, NL, NAME, STRING, OP, NEWLINE, NL, NL, NA...
# 12    [NL, NL, NAME, NAME, OP, NL, NAME, NAME, OP, N...
# 13    [NL, NL, NAME, NAME, OP, NL, NAME, NAME, OP, N...
# 14    [NL, NL, NAME, STRING, OP, NEWLINE, NAME, STRI...
# 15    [NL, NAME, STRING, OP, NEWLINE, NL, NAME, NAME...
# 19    [NL, NAME, STRING, OP, NEWLINE, NAME, STRING, ...
# 21    [NL, NAME, STRING, OP, NEWLINE, NAME, STRING, ...
# 23    [NL, NAME, STRING, OP, NEWLINE, NAME, STRING, ...
# 24    [NL, NAME, STRING, OP, NEWLINE, NAME, STRING, ...
# 25    [NL, NL, NAME, STRING, OP, NEWLINE, NL, NAME, ...
# 27    [NL, NAME, STRING, OP, NEWLINE, NAME, STRING, ...
# 32    [NL, NAME, NAME, OP, NL, NL, NL, NAME, NAME, N...
# 34    [NL, NAME, STRING, OP, NEWLINE, NAME, STRING, ...
# 37    [NL, NAME, STRING, OP, NEWLINE, NAME, STRING, ...
# 38    [NL, NAME, STRING, OP, NEWLINE, NL, NAME, NAME...
# 39    [NL, NAME, STRING, OP, NEWLINE, NL, NAME, NAME...
# 40    [NL, NAME, STRING, OP, NEWLINE, NAME, STRING, ...
# 42    [NL, NAME, STRING, OP, NEWLINE, NL, NAME, NAME...
# 45    [NL, NL, NAME, NAME, OP, NL, NAME, NAME, NAME,...
# 47    [NL, NAME, NAME, OP, NL, NL, NAME, OP, OP, NAM...
# 48    [NL, NAME, NAME, OP, NL, NAME, NAME, NAME, OP,...
# 50    [NAME, STRING, OP, NEWLINE, NL, NL, NAME, NAME...
# 51    [NAME, STRING, OP, NEWLINE, NAME, STRING, OP, ...
# 54    [NAME, STRING, OP, NEWLINE, NAME, STRING, OP, ...
# 55    [NAME, STRING, OP, NEWLINE, NAME, STRING, OP, ...
# 57    [NAME, STRING, OP, NEWLINE, NL, NL, NAME, NAME...
# ...                                                 ...
# 986   [NL, NAME, NAME, OP, NL, NAME, NAME, NAME, OP,...
# 987   [NL, NAME, STRING, OP, NEWLINE, NAME, STRING, ...
# 991   [NL, NAME, STRING, OP, NEWLINE, NL, NAME, NAME...
# 992   [NL, NAME, STRING, OP, NEWLINE, NAME, STRING, ...
# 993   [NL, NAME, STRING, OP, NEWLINE, NAME, STRING, ...
# 995   [NAME, NAME, OP, NL, NAME, NAME, OP, NAME, NAM...
# 999   [NL, NL, NAME, NAME, OP, NL, NL, NAME, NAME, N...
# 1000  [NAME, NAME, OP, NL, NAME, NAME, OP, NAME, NAM...
# 1001  [NL, NAME, NAME, OP, NL, NAME, NAME, OP, NAME,...
# 1005  [NL, NL, NAME, STRING, OP, NEWLINE, NAME, STRI...
# 1006  [NL, NL, NAME, STRING, OP, NEWLINE, NAME, STRI...
# 1007  [NL, NAME, NAME, OP, NL, NAME, NAME, NAME, OP,...
# 1008  [NL, NL, NAME, STRING, OP, NEWLINE, NAME, STRI...
# 1009  [NL, NL, NAME, STRING, OP, NEWLINE, NAME, STRI...
# 1014  [NL, NL, NAME, STRING, OP, NEWLINE, NAME, STRI...
# 1015  [NL, NL, NAME, STRING, OP, NEWLINE, NAME, STRI...
# 1019  [NL, NL, NAME, NAME, OP, NL, NAME, NAME, OP, O...
# 1020  [NL, NAME, STRING, OP, NEWLINE, NAME, STRING, ...
# 1022  [NL, NAME, STRING, OP, NEWLINE, NL, INDENT, NA...
# 1025  [NL, NL, NAME, NAME, OP, NL, NL, NAME, NAME, N...
# 1027  [NL, NAME, STRING, OP, NEWLINE, NAME, STRING, ...
# 1028  [NL, NL, NAME, STRING, OP, NEWLINE, NAME, STRI...
# 1029  [NL, NAME, STRING, OP, NEWLINE, NAME, STRING, ...
# 1030  [NL, NAME, NAME, OP, NL, NAME, NAME, NAME, OP,...
# 1032  [NL, INDENT, NAME, NUMBER, OP, NAME, NAME, OP,...
# 1035  [NL, INDENT, NAME, NUMBER, OP, NAME, NAME, OP,...
# 1036  [NL, INDENT, NAME, NUMBER, OP, NAME, NAME, OP,...
# 1038  [NAME, NAME, OP, NUMBER, NUMBER, OP, NEWLINE, ...
# 1039  [NL, NAME, NAME, OP, NL, NAME, NAME, OP, NAME,...
# 1041  [NL, NAME, NAME, OP, NL, NAME, NAME, NAME, OP,...
#
#                                                  values
# 3     ['\n', 'contract', 'PullPayInterface', '{', '\...
# 4     ['\n', '\n', 'contract', 'ERC20Basic', '{', '\...
# 6     ['\n', 'contract', 'Migrations', '{', '\n', 'a...
# 7     ['\n', 'import', "'./ERC20Basic.sol'", ';', '\...
# 11    ['\n', '\n', 'import', "'./ERC223Basic.sol'", ...
# 12    ['\n', '\n', 'contract', 'ERC223ReceivingContr...
# 13    ['\n', '\n', 'library', 'SafeMath', '{', '\n',...
# 14    ['\n', '\n', 'import', "'../SafeMath.sol'", ';...
# 15    ['\n', 'import', '"../ownership/Ownable.sol"',...
# 19    ['\n', 'import', '"../ERC20.sol"', ';', '\n', ...
# 21    ['\n', 'import', '"../ERC20Basic.sol"', ';', '...
# 23    ['\n', 'import', "'../controller/Controller.so...
# 24    ['\n', 'import', "'../controller/Controller.so...
# 25    ['\n', '\n', 'import', "'../policies/PowerEven...
# 27    ['\n', 'import', "'../controller/Controller.so...
# 32    ['\n', 'contract', 'ControllerInterface', '{',...
# 34    ['\n', 'import', '"../SafeMath.sol"', ';', '\n...
# 37    ['\n', 'import', '"../satelites/Power.sol"', '...
# 38    ['\n', 'import', '"../satelites/Storage.sol"',...
# 39    ['\n', 'import', '"./PowerEnabled.sol"', ';', ...
# 40    ['\n', 'import', '"../satelites/PullPayment.so...
# 42    ['\n', 'import', '"./Governable.sol"', ';', '\...
# 45    ['\n', '\n', 'contract', 'Ownable', '{', '\n',...
# 47    ['\n', 'contract', 'Governable', '{', '\n', '\...
# 48    ['\n', 'contract', 'Migrations', '{', '\n', 'a...
# 50    ['import', '"../Markets/StandardMarketWithPric...
# 51    ['import', '"../Markets/Market.sol"', ';', '\n...
# 54    ['import', '"../Events/Event.sol"', ';', '\n',...
# 55    ['import', '"../Events/Event.sol"', ';', '\n',...
# 57    ['import', '"../Markets/Campaign.sol"', ';', '...
# ...                                                 ...
# 986   ['\n', 'contract', 'Migrations', '{', '\n', 'a...
# 987   ['\n', 'import', "'./LordCoin.sol'", ';', '\n'...
# 991   ['\n', 'import', "'./LordCoinICO.sol'", ';', '...
# 992   ['\n', 'import', "'./LordCoin.sol'", ';', '\n'...
# 993   ['\n', 'import', "'./LordCoin.sol'", ';', '\n'...
# 995   ['contract', 'SafeMath', '{', '\n', 'function'...
# 999   ['\n', '\n', 'contract', 'MultiSigWallet', '{'...
# 1000  ['contract', 'SafeMath', '{', '\n', 'function'...
# 1001  ['\n', 'contract', 'SafeMath', '{', '\n', 'fun...
# 1005  ['\n', '\n', 'import', "'./FlipToken.sol'", ';...
# 1006  ['\n', '\n', 'import', "'./FlipCrowdsale.sol'"...
# 1007  ['\n', 'contract', 'Migrations', '{', '\n', 'a...
# 1008  ['\n', '\n', 'import', "'zeppelin-solidity/con...
# 1009  ['\n', '\n', 'import', "'./FlipCrowdsale.sol'"...
# 1014  ['\n', '\n', 'import', "'./PreSale.sol'", ';',...
# 1015  ['\n', '\n', 'import', "'zeppelin-solidity/con...
# 1019  ['\n', '\n', 'contract', 'AbstractSale', '{', ...
# 1020  ['\n', 'import', '"./interface/Controlled.sol"...
# 1022  ['\n', 'import', '"./MiniMeIrrevocableVestedTo...
# 1025  ['\n', '\n', 'contract', 'MultiSigWallet', '{'...
# 1027  ['\n', 'import', '"./interface/Controller.sol"...
# 1028  ['\n', '\n', 'import', '"./MiniMeToken.sol"', ...
# 1029  ['\n', 'import', '"zeppelin/SafeMath.sol"', ';...
# 1030  ['\n', 'contract', 'Migrations', '{', '\n', 'a...
# 1032  ['\n', '    ', 'Copyright', '2017', ',', 'Jorg...
# 1035  ['\n', '    ', 'Copyright', '2017', ',', 'Jorg...
# 1036  ['\n', '    ', 'Copyright', '2017', ',', 'Jord...
# 1038  ['pragma', 'solidity', '^', '0.4', '.18', ';',...
# 1039  ['\n', 'library', 'SafeMath', '{', '\n', 'func...
# 1041  ['\n', 'contract', 'Migrations', '{', '\n', 'a...
#
# [522 rows x 7 columns]

# %%
# 2. Plot the Data (with matplotlib or port over to R)

# %%
tokens = pd.DataFrame()

# %%
def expand_df(df):
    lens = [len(item) for item in df['types']]
    return pd.DataFrame( {
        "file_name" : np.repeat(df['file_name'].values, lens), 
        "class" : np.repeat(df['class'].values, lens), 
        "company" : np.repeat(df['company'].values, lens), 
        "root" : np.repeat(df['root'].values, lens), 
        "type" : np.concatenate(df['types'].values),
        "value" : np.concatenate(df['values'].values),
        "lines" : [item for sublist in df['lines'].values for item in sublist],
    })

# %%
tokens = expand_df(df_files)
len(tokens)
# len(tokens[tokens.isnull().any(axis=1)])
# Out:
# 219914

# %%
# type freq
token_type_freq = pd.Series.value_counts(tokens.type, sort=True)
print(token_type_freq)
# Out:
# OP            91444
# NAME          86899
# NL            33396
# NUMBER         3737
# NEWLINE        1814
# STRING         1610
# ENDMARKER       522
# ERRORTOKEN      440
# INDENT           26
# DEDENT           26
# Name: type, dtype: int64

# %%
# value freq
freq = pd.Series.value_counts(tokens.value, sort=True)
# print(freq[:50])

# %%
# tokens[tokens['type']=='ERRORTOKEN']

# %%
freq = pd.Series.value_counts(tokens[tokens.type == 'OP'].value, sort=True)
# print(freq[:50])

# %%
freq = pd.Series.value_counts(tokens[tokens.type == 'NAME'].value, sort=True)
# print(freq[:100])

# %%
import StringIO
def tokenize_string(string):
    tokens_dict = {
        'line': [],
        'line_se': [],
        'type': [],
        'value': [],
    }
    tokens_list = []
    buf = StringIO.StringIO(string)
    token_generator = tokenize.generate_tokens(buf.readline)
    for type, token, (srow, scol), (erow, ecol), line in token_generator:
        tokens_dict['line'].append(srow)        
        tokens_dict['line_se'].append(((srow, scol), (erow, ecol)))    
        tokens_dict['type'].append(tokenize.tok_name[type])        
        tokens_dict['value'].append(repr(token))
        tokens_list.append([srow, tokenize.tok_name[type], repr(token)])
            
    tokens_dict['type'] = ['NL' if x == 'NEWLINE' else x for x in tokens_dict['type']]

    return tokens_dict


def tokenize_string_from_row(row):
#     filename = get_filename_for_row(row)
#     print filename
    tokens_dict = tokenize_string(row['src'])
    row['lines'] = tokens_dict['line_se']
    row['types'] = tokens_dict['type']
    row['values'] = tokens_dict['value']
    return row

# %%
# strips pragma statements and comments
def read_src_nocomments(file_name, return_only_comments=False):
    with open(file_name, 'r') as f:
        src_list = []
        comments_list = []
        for line in f.readlines():
            # skip pragma
            if re.match('pragma solidity .*;', line.strip()):
                continue
            # single or multiline comments
            if re.match('/', line.strip()) or re.match('\*', line.strip()):
                comments_list.append(line)
                continue
            # inline comments
#             if re.search('//', line):
#                 inline_comment = re.findall('[\s]*//.*\n', line)
#                 comments_list.extend(inline_comment)
#                 line = re.sub('[\s]*//.*\n', '\n', line)
#                 continue
                
            # add current src line
            src_list.append(line)
            
        if return_only_comments:
            return ''.join(comments_list)
        else:
            return ''.join(src_list)

def get_file_src(row):
    return read_src(get_filename_for_row(row))

def get_file_src_nocomments(row):
    return read_src_nocomments(get_filename_for_row(row))

def get_file_src_only_comments(row):
    return read_src_nocomments(get_filename_for_row(row), return_only_comments=True)
    
df_files['src'] = df_files.apply(get_file_src_nocomments, axis=1)
df_files
# Out:
#                                      file_name        root   class  \
# 3                         PullPayInterface.sol              notICO
# 4                               ERC20Basic.sol              notICO
# 6                               Migrations.sol              notICO
# 7                              ERC223Basic.sol              notICO
# 11                                   ERC20.sol              notICO
# 12                 ERC223ReceivingContract.sol              notICO
# 13                                SafeMath.sol              notICO
# 14                             PullPayment.sol   satelites  notICO
# 15                                 Storage.sol   satelites  notICO
# 19                                    Nutz.sol   satelites  notICO
# 21                                   Power.sol   satelites  notICO
# 23                            UpgradeEvent.sol    policies  notICO
# 24                              PowerEvent.sol    policies  notICO
# 25                   PowerEventReplacement.sol    policies  notICO
# 27                     UpgradeEventCompact.sol    policies  notICO
# 32                     ControllerInterface.sol  controller  notICO
# 34                             NutzEnabled.sol  controller  notICO
# 37                            PowerEnabled.sol  controller  notICO
# 38                          StorageEnabled.sol  controller  notICO
# 39                              Controller.sol  controller  notICO
# 40                           MarketEnabled.sol  controller  notICO
# 42                                Pausable.sol   ownership  notICO
# 45                                 Ownable.sol   ownership  notICO
# 47                              Governable.sol   ownership  notICO
# 48                              Migrations.sol              notICO
# 50    StandardMarketWithPriceLoggerFactory.sol     Markets  notICO
# 51                          StandardMarket.sol     Markets  notICO
# 54                                Campaign.sol     Markets  notICO
# 55                                  Market.sol     Markets  notICO
# 57                         CampaignFactory.sol     Markets  notICO
# ...                                        ...         ...     ...
# 986                             Migrations.sol                 ICO
# 987                            LordCoinICO.sol                 ICO
# 991                        LordCoinICOMock.sol                 ICO
# 992                              LM2Wallet.sol                 ICO
# 993                           LordCoinLock.sol                 ICO
# 995            NapoleonXCrowdsaleTokenTest.sol                 ICO
# 999                         MultiSigWallet.sol                 ICO
# 1000               NapoleonXCrowdsaleToken.sol                 ICO
# 1001                             Greenlist.sol                 ICO
# 1005                             Timelocks.sol                 ICO
# 1006                              MainSale.sol                 ICO
# 1007                            Migrations.sol                 ICO
# 1008                             FlipToken.sol                 ICO
# 1009                               PreSale.sol                 ICO
# 1014                       PreSaleExtended.sol                 ICO
# 1015                         FlipCrowdsale.sol                 ICO
# 1019                            SaleWallet.sol                 ICO
# 1020                           MiniMeToken.sol                 ICO
# 1022                                   ANT.sol                 ICO
# 1025                        MultisigWallet.sol                 ICO
# 1027                         ANPlaceholder.sol                 ICO
# 1028          MiniMeIrrevocableVestedToken.sol                 ICO
# 1029                       AragonTokenSale.sol                 ICO
# 1030                            Migrations.sol        misc     ICO
# 1032                            Controlled.sol   interface     ICO
# 1035                            Controller.sol   interface     ICO
# 1036                ApproveAndCallReceiver.sol   interface     ICO
# 1038                        BitDegreeToken.sol                 ICO
# 1039                    BitDegreeCrowdsale.sol                 ICO
# 1041                            Migrations.sol                 ICO
#
#             company                                                src
# 3        AceBusters  \ncontract PullPayInterface {\n  function asyn...
# 4        AceBusters  \n\ncontract ERC20Basic {\n  function totalSup...
# 6        AceBusters  \ncontract Migrations {\n  address public owne...
# 7        AceBusters  \nimport './ERC20Basic.sol';\n\ncontract ERC22...
# 11       AceBusters  \n\nimport './ERC223Basic.sol';\n\n\ncontract ...
# 12       AceBusters  \n \ncontract ERC223ReceivingContract {\n    f...
# 13       AceBusters  \n\nlibrary SafeMath {\n  function mul(uint256...
# 14       AceBusters  \n\nimport '../SafeMath.sol';\nimport "../owne...
# 15       AceBusters  \nimport "../ownership/Ownable.sol";\n\ncontra...
# 19       AceBusters  \nimport "../ERC20.sol";\nimport "../ownership...
# 21       AceBusters  \nimport "../ERC20Basic.sol";\nimport "../owne...
# 23       AceBusters  \nimport '../controller/Controller.sol';\nimpo...
# 24       AceBusters  \nimport '../controller/Controller.sol';\nimpo...
# 25       AceBusters  \n\nimport '../policies/PowerEvent.sol';\n\nco...
# 27       AceBusters  \nimport '../controller/Controller.sol';\nimpo...
# 32       AceBusters  \ncontract ControllerInterface {\n\n\n  bool p...
# 34       AceBusters  \nimport "../SafeMath.sol";\nimport "./Storage...
# 37       AceBusters  \nimport "../satelites/Power.sol";\nimport "./...
# 38       AceBusters  \nimport "../satelites/Storage.sol";\n\ncontra...
# 39       AceBusters  \nimport "./PowerEnabled.sol";\n\ncontract Con...
# 40       AceBusters  \nimport "../satelites/PullPayment.sol";\nimpo...
# 42       AceBusters  \nimport "./Governable.sol";\n\ncontract Pausa...
# 45       AceBusters  \n\ncontract Ownable {\n  address public owner...
# 47       AceBusters  \ncontract Governable {\n\n  address[] public ...
# 48    GnosisMarkets  \ncontract Migrations {\n  address public owne...
# 50    GnosisMarkets  import "../Markets/StandardMarketWithPriceLogg...
# 51    GnosisMarkets  import "../Markets/Market.sol";\nimport "../To...
# 54    GnosisMarkets  import "../Events/Event.sol";\nimport "../Mark...
# 55    GnosisMarkets  import "../Events/Event.sol";\nimport "../Mark...
# 57    GnosisMarkets  import "../Markets/Campaign.sol";\n\n\ncontrac...
# ...             ...                                                ...
# 986      LordMancer  \ncontract Migrations {\n  address public owne...
# 987      LordMancer  \nimport './LordCoin.sol';\nimport 'zeppelin-s...
# 991      LordMancer  \nimport './LordCoinICO.sol';\n\ncontract Lord...
# 992      LordMancer  \nimport './LordCoin.sol';\nimport 'zeppelin-s...
# 993      LordMancer  \nimport './LordCoin.sol';\nimport 'zeppelin-s...
# 995       NapoleonX  contract SafeMath {\n  function safeMul(uint a...
# 999       NapoleonX  \n\ncontract MultiSigWallet {\n\n    uint cons...
# 1000      NapoleonX  contract SafeMath {\n  function safeMul(uint a...
# 1001      NapoleonX  \ncontract SafeMath {\n  function safeMul(uint...
# 1005       Gameflip  \n\nimport './FlipToken.sol';\nimport 'zeppeli...
# 1006       Gameflip  \n\nimport './FlipCrowdsale.sol';\nimport './F...
# 1007       Gameflip  \ncontract Migrations {\n  address public owne...
# 1008       Gameflip  \n\nimport 'zeppelin-solidity/contracts/token/...
# 1009       Gameflip  \n\nimport './FlipCrowdsale.sol';\nimport './F...
# 1014       Gameflip  \n\nimport './PreSale.sol';\nimport './FlipTok...
# 1015       Gameflip  \n\nimport 'zeppelin-solidity/contracts/crowds...
# 1019         Aragon  \n\ncontract AbstractSale {\n  function saleFi...
# 1020         Aragon  \nimport "./interface/Controlled.sol";\nimport...
# 1022         Aragon  \nimport "./MiniMeIrrevocableVestedToken.sol";...
# 1025         Aragon  \n\ncontract MultiSigWallet {\n\n    uint cons...
# 1027         Aragon  \nimport "./interface/Controller.sol";\nimport...
# 1028         Aragon  \n\nimport "./MiniMeToken.sol";\nimport "zeppe...
# 1029         Aragon  \nimport "zeppelin/SafeMath.sol";\nimport "./i...
# 1030         Aragon  \ncontract Migrations {\n  address public owne...
# 1032         Aragon  \n    Copyright 2017, Jorge Izquierdo (Aragon ...
# 1035         Aragon  \n    Copyright 2017, Jorge Izquierdo (Aragon ...
# 1036         Aragon  \n    Copyright 2017, Jordi Baylina (Giveth)\n...
# 1038      BitDegree  pragma solidity^0.4.18;\n\nimport "zeppelin-so...
# 1039      BitDegree  \nlibrary SafeMath {\n    function mul(uint256...
# 1041      BitDegree  \ncontract Migrations {\n  address public owne...
#
# [522 rows x 5 columns]

# %%
df_files = df_files.apply(tokenize_string_from_row, axis=1)
df_files
# Out:
#                                      file_name        root   class  \
# 3                         PullPayInterface.sol              notICO
# 4                               ERC20Basic.sol              notICO
# 6                               Migrations.sol              notICO
# 7                              ERC223Basic.sol              notICO
# 11                                   ERC20.sol              notICO
# 12                 ERC223ReceivingContract.sol              notICO
# 13                                SafeMath.sol              notICO
# 14                             PullPayment.sol   satelites  notICO
# 15                                 Storage.sol   satelites  notICO
# 19                                    Nutz.sol   satelites  notICO
# 21                                   Power.sol   satelites  notICO
# 23                            UpgradeEvent.sol    policies  notICO
# 24                              PowerEvent.sol    policies  notICO
# 25                   PowerEventReplacement.sol    policies  notICO
# 27                     UpgradeEventCompact.sol    policies  notICO
# 32                     ControllerInterface.sol  controller  notICO
# 34                             NutzEnabled.sol  controller  notICO
# 37                            PowerEnabled.sol  controller  notICO
# 38                          StorageEnabled.sol  controller  notICO
# 39                              Controller.sol  controller  notICO
# 40                           MarketEnabled.sol  controller  notICO
# 42                                Pausable.sol   ownership  notICO
# 45                                 Ownable.sol   ownership  notICO
# 47                              Governable.sol   ownership  notICO
# 48                              Migrations.sol              notICO
# 50    StandardMarketWithPriceLoggerFactory.sol     Markets  notICO
# 51                          StandardMarket.sol     Markets  notICO
# 54                                Campaign.sol     Markets  notICO
# 55                                  Market.sol     Markets  notICO
# 57                         CampaignFactory.sol     Markets  notICO
# ...                                        ...         ...     ...
# 986                             Migrations.sol                 ICO
# 987                            LordCoinICO.sol                 ICO
# 991                        LordCoinICOMock.sol                 ICO
# 992                              LM2Wallet.sol                 ICO
# 993                           LordCoinLock.sol                 ICO
# 995            NapoleonXCrowdsaleTokenTest.sol                 ICO
# 999                         MultiSigWallet.sol                 ICO
# 1000               NapoleonXCrowdsaleToken.sol                 ICO
# 1001                             Greenlist.sol                 ICO
# 1005                             Timelocks.sol                 ICO
# 1006                              MainSale.sol                 ICO
# 1007                            Migrations.sol                 ICO
# 1008                             FlipToken.sol                 ICO
# 1009                               PreSale.sol                 ICO
# 1014                       PreSaleExtended.sol                 ICO
# 1015                         FlipCrowdsale.sol                 ICO
# 1019                            SaleWallet.sol                 ICO
# 1020                           MiniMeToken.sol                 ICO
# 1022                                   ANT.sol                 ICO
# 1025                        MultisigWallet.sol                 ICO
# 1027                         ANPlaceholder.sol                 ICO
# 1028          MiniMeIrrevocableVestedToken.sol                 ICO
# 1029                       AragonTokenSale.sol                 ICO
# 1030                            Migrations.sol        misc     ICO
# 1032                            Controlled.sol   interface     ICO
# 1035                            Controller.sol   interface     ICO
# 1036                ApproveAndCallReceiver.sol   interface     ICO
# 1038                        BitDegreeToken.sol                 ICO
# 1039                    BitDegreeCrowdsale.sol                 ICO
# 1041                            Migrations.sol                 ICO
#
#             company                                                src  \
# 3        AceBusters  \ncontract PullPayInterface {\n  function asyn...
# 4        AceBusters  \n\ncontract ERC20Basic {\n  function totalSup...
# 6        AceBusters  \ncontract Migrations {\n  address public owne...
# 7        AceBusters  \nimport './ERC20Basic.sol';\n\ncontract ERC22...
# 11       AceBusters  \n\nimport './ERC223Basic.sol';\n\n\ncontract ...
# 12       AceBusters  \n \ncontract ERC223ReceivingContract {\n    f...
# 13       AceBusters  \n\nlibrary SafeMath {\n  function mul(uint256...
# 14       AceBusters  \n\nimport '../SafeMath.sol';\nimport "../owne...
# 15       AceBusters  \nimport "../ownership/Ownable.sol";\n\ncontra...
# 19       AceBusters  \nimport "../ERC20.sol";\nimport "../ownership...
# 21       AceBusters  \nimport "../ERC20Basic.sol";\nimport "../owne...
# 23       AceBusters  \nimport '../controller/Controller.sol';\nimpo...
# 24       AceBusters  \nimport '../controller/Controller.sol';\nimpo...
# 25       AceBusters  \n\nimport '../policies/PowerEvent.sol';\n\nco...
# 27       AceBusters  \nimport '../controller/Controller.sol';\nimpo...
# 32       AceBusters  \ncontract ControllerInterface {\n\n\n  bool p...
# 34       AceBusters  \nimport "../SafeMath.sol";\nimport "./Storage...
# 37       AceBusters  \nimport "../satelites/Power.sol";\nimport "./...
# 38       AceBusters  \nimport "../satelites/Storage.sol";\n\ncontra...
# 39       AceBusters  \nimport "./PowerEnabled.sol";\n\ncontract Con...
# 40       AceBusters  \nimport "../satelites/PullPayment.sol";\nimpo...
# 42       AceBusters  \nimport "./Governable.sol";\n\ncontract Pausa...
# 45       AceBusters  \n\ncontract Ownable {\n  address public owner...
# 47       AceBusters  \ncontract Governable {\n\n  address[] public ...
# 48    GnosisMarkets  \ncontract Migrations {\n  address public owne...
# 50    GnosisMarkets  import "../Markets/StandardMarketWithPriceLogg...
# 51    GnosisMarkets  import "../Markets/Market.sol";\nimport "../To...
# 54    GnosisMarkets  import "../Events/Event.sol";\nimport "../Mark...
# 55    GnosisMarkets  import "../Events/Event.sol";\nimport "../Mark...
# 57    GnosisMarkets  import "../Markets/Campaign.sol";\n\n\ncontrac...
# ...             ...                                                ...
# 986      LordMancer  \ncontract Migrations {\n  address public owne...
# 987      LordMancer  \nimport './LordCoin.sol';\nimport 'zeppelin-s...
# 991      LordMancer  \nimport './LordCoinICO.sol';\n\ncontract Lord...
# 992      LordMancer  \nimport './LordCoin.sol';\nimport 'zeppelin-s...
# 993      LordMancer  \nimport './LordCoin.sol';\nimport 'zeppelin-s...
# 995       NapoleonX  contract SafeMath {\n  function safeMul(uint a...
# 999       NapoleonX  \n\ncontract MultiSigWallet {\n\n    uint cons...
# 1000      NapoleonX  contract SafeMath {\n  function safeMul(uint a...
# 1001      NapoleonX  \ncontract SafeMath {\n  function safeMul(uint...
# 1005       Gameflip  \n\nimport './FlipToken.sol';\nimport 'zeppeli...
# 1006       Gameflip  \n\nimport './FlipCrowdsale.sol';\nimport './F...
# 1007       Gameflip  \ncontract Migrations {\n  address public owne...
# 1008       Gameflip  \n\nimport 'zeppelin-solidity/contracts/token/...
# 1009       Gameflip  \n\nimport './FlipCrowdsale.sol';\nimport './F...
# 1014       Gameflip  \n\nimport './PreSale.sol';\nimport './FlipTok...
# 1015       Gameflip  \n\nimport 'zeppelin-solidity/contracts/crowds...
# 1019         Aragon  \n\ncontract AbstractSale {\n  function saleFi...
# 1020         Aragon  \nimport "./interface/Controlled.sol";\nimport...
# 1022         Aragon  \nimport "./MiniMeIrrevocableVestedToken.sol";...
# 1025         Aragon  \n\ncontract MultiSigWallet {\n\n    uint cons...
# 1027         Aragon  \nimport "./interface/Controller.sol";\nimport...
# 1028         Aragon  \n\nimport "./MiniMeToken.sol";\nimport "zeppe...
# 1029         Aragon  \nimport "zeppelin/SafeMath.sol";\nimport "./i...
# 1030         Aragon  \ncontract Migrations {\n  address public owne...
# 1032         Aragon  \n    Copyright 2017, Jorge Izquierdo (Aragon ...
# 1035         Aragon  \n    Copyright 2017, Jorge Izquierdo (Aragon ...
# 1036         Aragon  \n    Copyright 2017, Jordi Baylina (Giveth)\n...
# 1038      BitDegree  pragma solidity^0.4.18;\n\nimport "zeppelin-so...
# 1039      BitDegree  \nlibrary SafeMath {\n    function mul(uint256...
# 1041      BitDegree  \ncontract Migrations {\n  address public owne...
#
#                                                   lines  \
# 3     [((1, 0), (1, 1)), ((2, 0), (2, 8)), ((2, 9), ...
# 4     [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 6     [((1, 0), (1, 1)), ((2, 0), (2, 8)), ((2, 9), ...
# 7     [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 11    [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 12    [((1, 0), (1, 1)), ((2, 1), (2, 2)), ((3, 0), ...
# 13    [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 14    [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 15    [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 19    [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 21    [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 23    [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 24    [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 25    [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 27    [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 32    [((1, 0), (1, 1)), ((2, 0), (2, 8)), ((2, 9), ...
# 34    [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 37    [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 38    [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 39    [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 40    [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 42    [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 45    [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 47    [((1, 0), (1, 1)), ((2, 0), (2, 8)), ((2, 9), ...
# 48    [((1, 0), (1, 1)), ((2, 0), (2, 8)), ((2, 9), ...
# 50    [((1, 0), (1, 6)), ((1, 7), (1, 53)), ((1, 53)...
# 51    [((1, 0), (1, 6)), ((1, 7), (1, 30)), ((1, 30)...
# 54    [((1, 0), (1, 6)), ((1, 7), (1, 28)), ((1, 28)...
# 55    [((1, 0), (1, 6)), ((1, 7), (1, 28)), ((1, 28)...
# 57    [((1, 0), (1, 6)), ((1, 7), (1, 32)), ((1, 32)...
# ...                                                 ...
# 986   [((1, 0), (1, 1)), ((2, 0), (2, 8)), ((2, 9), ...
# 987   [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 991   [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 992   [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 993   [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 995   [((1, 0), (1, 8)), ((1, 9), (1, 17)), ((1, 18)...
# 999   [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 1000  [((1, 0), (1, 8)), ((1, 9), (1, 17)), ((1, 18)...
# 1001  [((1, 0), (1, 1)), ((2, 0), (2, 8)), ((2, 9), ...
# 1005  [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 1006  [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 1007  [((1, 0), (1, 1)), ((2, 0), (2, 8)), ((2, 9), ...
# 1008  [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 1009  [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 1014  [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 1015  [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 1019  [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 1020  [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 1022  [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 1025  [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 1027  [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 1028  [((1, 0), (1, 1)), ((2, 0), (2, 1)), ((3, 0), ...
# 1029  [((1, 0), (1, 1)), ((2, 0), (2, 6)), ((2, 7), ...
# 1030  [((1, 0), (1, 1)), ((2, 0), (2, 8)), ((2, 9), ...
# 1032  [((1, 0), (1, 1)), ((2, 0), (2, 4)), ((2, 4), ...
# 1035  [((1, 0), (1, 1)), ((2, 0), (2, 4)), ((2, 4), ...
# 1036  [((1, 0), (1, 1)), ((2, 0), (2, 4)), ((2, 4), ...
# 1038  [((1, 0), (1, 6)), ((1, 7), (1, 15)), ((1, 15)...
# 1039  [((1, 0), (1, 1)), ((2, 0), (2, 7)), ((2, 8), ...
# 1041  [((1, 0), (1, 1)), ((2, 0), (2, 8)), ((2, 9), ...
#
#                                                   types  \
# 3     [NL, NAME, NAME, OP, NL, NAME, NAME, OP, NAME,...
# 4     [NL, NL, NAME, NAME, OP, NL, NAME, NAME, OP, O...
# 6     [NL, NAME, NAME, OP, NL, NAME, NAME, NAME, OP,...
# 7     [NL, NAME, STRING, OP, NL, NL, NAME, NAME, NAM...
# 11    [NL, NL, NAME, STRING, OP, NL, NL, NL, NAME, N...
# 12    [NL, NL, NAME, NAME, OP, NL, NAME, NAME, OP, N...
# 13    [NL, NL, NAME, NAME, OP, NL, NAME, NAME, OP, N...
# 14    [NL, NL, NAME, STRING, OP, NL, NAME, STRING, O...
# 15    [NL, NAME, STRING, OP, NL, NL, NAME, NAME, NAM...
# 19    [NL, NAME, STRING, OP, NL, NAME, STRING, OP, N...
# 21    [NL, NAME, STRING, OP, NL, NAME, STRING, OP, N...
# 23    [NL, NAME, STRING, OP, NL, NAME, STRING, OP, N...
# 24    [NL, NAME, STRING, OP, NL, NAME, STRING, OP, N...
# 25    [NL, NL, NAME, STRING, OP, NL, NL, NAME, NAME,...
# 27    [NL, NAME, STRING, OP, NL, NAME, STRING, OP, N...
# 32    [NL, NAME, NAME, OP, NL, NL, NL, NAME, NAME, N...
# 34    [NL, NAME, STRING, OP, NL, NAME, STRING, OP, N...
# 37    [NL, NAME, STRING, OP, NL, NAME, STRING, OP, N...
# 38    [NL, NAME, STRING, OP, NL, NL, NAME, NAME, OP,...
# 39    [NL, NAME, STRING, OP, NL, NL, NAME, NAME, NAM...
# 40    [NL, NAME, STRING, OP, NL, NAME, STRING, OP, N...
# 42    [NL, NAME, STRING, OP, NL, NL, NAME, NAME, NAM...
# 45    [NL, NL, NAME, NAME, OP, NL, NAME, NAME, NAME,...
# 47    [NL, NAME, NAME, OP, NL, NL, NAME, OP, OP, NAM...
# 48    [NL, NAME, NAME, OP, NL, NAME, NAME, NAME, OP,...
# 50    [NAME, STRING, OP, NL, NL, NL, NAME, NAME, OP,...
# 51    [NAME, STRING, OP, NL, NAME, STRING, OP, NL, N...
# 54    [NAME, STRING, OP, NL, NAME, STRING, OP, NL, N...
# 55    [NAME, STRING, OP, NL, NAME, STRING, OP, NL, N...
# 57    [NAME, STRING, OP, NL, NL, NL, NAME, NAME, OP,...
# ...                                                 ...
# 986   [NL, NAME, NAME, OP, NL, NAME, NAME, NAME, OP,...
# 987   [NL, NAME, STRING, OP, NL, NAME, STRING, OP, N...
# 991   [NL, NAME, STRING, OP, NL, NL, NAME, NAME, NAM...
# 992   [NL, NAME, STRING, OP, NL, NAME, STRING, OP, N...
# 993   [NL, NAME, STRING, OP, NL, NAME, STRING, OP, N...
# 995   [NAME, NAME, OP, NL, NAME, NAME, OP, NAME, NAM...
# 999   [NL, NL, NAME, NAME, OP, NL, NL, NAME, NAME, N...
# 1000  [NAME, NAME, OP, NL, NAME, NAME, OP, NAME, NAM...
# 1001  [NL, NAME, NAME, OP, NL, NAME, NAME, OP, NAME,...
# 1005  [NL, NL, NAME, STRING, OP, NL, NAME, STRING, O...
# 1006  [NL, NL, NAME, STRING, OP, NL, NAME, STRING, O...
# 1007  [NL, NAME, NAME, OP, NL, NAME, NAME, NAME, OP,...
# 1008  [NL, NL, NAME, STRING, OP, NL, NAME, STRING, O...
# 1009  [NL, NL, NAME, STRING, OP, NL, NAME, STRING, O...
# 1014  [NL, NL, NAME, STRING, OP, NL, NAME, STRING, O...
# 1015  [NL, NL, NAME, STRING, OP, NL, NAME, STRING, O...
# 1019  [NL, NL, NAME, NAME, OP, NL, NAME, NAME, OP, O...
# 1020  [NL, NAME, STRING, OP, NL, NAME, STRING, OP, N...
# 1022  [NL, NAME, STRING, OP, NL, NL, INDENT, NAME, N...
# 1025  [NL, NL, NAME, NAME, OP, NL, NL, NAME, NAME, N...
# 1027  [NL, NAME, STRING, OP, NL, NAME, STRING, OP, N...
# 1028  [NL, NL, NAME, STRING, OP, NL, NAME, STRING, O...
# 1029  [NL, NAME, STRING, OP, NL, NAME, STRING, OP, N...
# 1030  [NL, NAME, NAME, OP, NL, NAME, NAME, NAME, OP,...
# 1032  [NL, INDENT, NAME, NUMBER, OP, NAME, NAME, OP,...
# 1035  [NL, INDENT, NAME, NUMBER, OP, NAME, NAME, OP,...
# 1036  [NL, INDENT, NAME, NUMBER, OP, NAME, NAME, OP,...
# 1038  [NAME, NAME, OP, NUMBER, NUMBER, OP, NL, NL, N...
# 1039  [NL, NAME, NAME, OP, NL, NAME, NAME, OP, NAME,...
# 1041  [NL, NAME, NAME, OP, NL, NAME, NAME, NAME, OP,...
#
#                                                  values
# 3     ['\n', 'contract', 'PullPayInterface', '{', '\...
# 4     ['\n', '\n', 'contract', 'ERC20Basic', '{', '\...
# 6     ['\n', 'contract', 'Migrations', '{', '\n', 'a...
# 7     ['\n', 'import', "'./ERC20Basic.sol'", ';', '\...
# 11    ['\n', '\n', 'import', "'./ERC223Basic.sol'", ...
# 12    ['\n', '\n', 'contract', 'ERC223ReceivingContr...
# 13    ['\n', '\n', 'library', 'SafeMath', '{', '\n',...
# 14    ['\n', '\n', 'import', "'../SafeMath.sol'", ';...
# 15    ['\n', 'import', '"../ownership/Ownable.sol"',...
# 19    ['\n', 'import', '"../ERC20.sol"', ';', '\n', ...
# 21    ['\n', 'import', '"../ERC20Basic.sol"', ';', '...
# 23    ['\n', 'import', "'../controller/Controller.so...
# 24    ['\n', 'import', "'../controller/Controller.so...
# 25    ['\n', '\n', 'import', "'../policies/PowerEven...
# 27    ['\n', 'import', "'../controller/Controller.so...
# 32    ['\n', 'contract', 'ControllerInterface', '{',...
# 34    ['\n', 'import', '"../SafeMath.sol"', ';', '\n...
# 37    ['\n', 'import', '"../satelites/Power.sol"', '...
# 38    ['\n', 'import', '"../satelites/Storage.sol"',...
# 39    ['\n', 'import', '"./PowerEnabled.sol"', ';', ...
# 40    ['\n', 'import', '"../satelites/PullPayment.so...
# 42    ['\n', 'import', '"./Governable.sol"', ';', '\...
# 45    ['\n', '\n', 'contract', 'Ownable', '{', '\n',...
# 47    ['\n', 'contract', 'Governable', '{', '\n', '\...
# 48    ['\n', 'contract', 'Migrations', '{', '\n', 'a...
# 50    ['import', '"../Markets/StandardMarketWithPric...
# 51    ['import', '"../Markets/Market.sol"', ';', '\n...
# 54    ['import', '"../Events/Event.sol"', ';', '\n',...
# 55    ['import', '"../Events/Event.sol"', ';', '\n',...
# 57    ['import', '"../Markets/Campaign.sol"', ';', '...
# ...                                                 ...
# 986   ['\n', 'contract', 'Migrations', '{', '\n', 'a...
# 987   ['\n', 'import', "'./LordCoin.sol'", ';', '\n'...
# 991   ['\n', 'import', "'./LordCoinICO.sol'", ';', '...
# 992   ['\n', 'import', "'./LordCoin.sol'", ';', '\n'...
# 993   ['\n', 'import', "'./LordCoin.sol'", ';', '\n'...
# 995   ['contract', 'SafeMath', '{', '\n', 'function'...
# 999   ['\n', '\n', 'contract', 'MultiSigWallet', '{'...
# 1000  ['contract', 'SafeMath', '{', '\n', 'function'...
# 1001  ['\n', 'contract', 'SafeMath', '{', '\n', 'fun...
# 1005  ['\n', '\n', 'import', "'./FlipToken.sol'", ';...
# 1006  ['\n', '\n', 'import', "'./FlipCrowdsale.sol'"...
# 1007  ['\n', 'contract', 'Migrations', '{', '\n', 'a...
# 1008  ['\n', '\n', 'import', "'zeppelin-solidity/con...
# 1009  ['\n', '\n', 'import', "'./FlipCrowdsale.sol'"...
# 1014  ['\n', '\n', 'import', "'./PreSale.sol'", ';',...
# 1015  ['\n', '\n', 'import', "'zeppelin-solidity/con...
# 1019  ['\n', '\n', 'contract', 'AbstractSale', '{', ...
# 1020  ['\n', 'import', '"./interface/Controlled.sol"...
# 1022  ['\n', 'import', '"./MiniMeIrrevocableVestedTo...
# 1025  ['\n', '\n', 'contract', 'MultiSigWallet', '{'...
# 1027  ['\n', 'import', '"./interface/Controller.sol"...
# 1028  ['\n', '\n', 'import', '"./MiniMeToken.sol"', ...
# 1029  ['\n', 'import', '"zeppelin/SafeMath.sol"', ';...
# 1030  ['\n', 'contract', 'Migrations', '{', '\n', 'a...
# 1032  ['\n', '    ', 'Copyright', '2017', ',', 'Jorg...
# 1035  ['\n', '    ', 'Copyright', '2017', ',', 'Jorg...
# 1036  ['\n', '    ', 'Copyright', '2017', ',', 'Jord...
# 1038  ['pragma', 'solidity', '^', '0.4', '.18', ';',...
# 1039  ['\n', 'library', 'SafeMath', '{', '\n', 'func...
# 1041  ['\n', 'contract', 'Migrations', '{', '\n', 'a...
#
# [522 rows x 8 columns]

# %%
tokens = expand_df(df_files)
len(tokens)
# Out:
# 219914

# %%
def token_frequencies(tokens):
    df = tokens.groupby(["type", "value"]).size().reset_index(name="num")
    num_tokens = len(tokens)
    df['num'] = df['num'].apply(lambda x: x / (1.0 * 522))
    return df.sort_values(by=['num'], ascending=False)

# %%
token_freq = token_frequencies(tokens)
token_freq_200 = token_freq[:200]
token_freq_200[:50]
# Out:
#            type       value        num
# 5120         NL        '\n'  67.452107
# 5455         OP         '('  32.482759
# 5456         OP         ')'  32.482759
# 5470         OP         ';'  27.270115
# 5462         OP         ','  16.657088
# 5465         OP         '.'  12.051724
# 5483         OP         '{'   9.772031
# 5485         OP         '}'   9.772031
# 5474         OP         '='   9.578544
# 2721       NAME  'function'   6.417625
# 1815       NAME   'address'   6.279693
# 5480         OP         '['   6.206897
# 5481         OP         ']'   6.206897
# 4096       NAME    'public'   5.143678
# 4909       NAME      'uint'   5.070881
# 4917       NAME   'uint256'   4.840996
# 4306       NAME   'returns'   3.934866
# 4300       NAME    'return'   3.649425
# 5122     NUMBER         '0'   2.994253
# 3150       NAME        'if'   2.747126
# 3605       NAME       'msg'   2.515326
# 4386       NAME    'sender'   2.249042
# 3142       NAME         'i'   2.204981
# 2000       NAME      'bool'   2.199234
# 4275       NAME   'require'   2.132184
# 3155       NAME    'import'   2.021073
# 5460         OP         '+'   2.000000
# 5475         OP        '=='   1.618774
# 2249       NAME  'constant'   1.580460
# 3201       NAME  'internal'   1.563218
# 2394       NAME        'db'   1.394636
# 5476         OP         '>'   1.392720
# 5454         OP         '&'   1.214559
# 2059       NAME   'bytes32'   1.204981
# 4893       NAME      'true'   1.137931
# 5016       NAME     'value'   1.078544
# 2257       NAME  'contract'   1.065134
# 1696       NAME    '_value'   1.024904
# 5471         OP         '<'   1.009579
# 1     ENDMARKER          ''   1.000000
# 3389       NAME    'length'   0.990421
# 3942       NAME     'owner'   0.977011
# 5227     NUMBER         '1'   0.969349
# 4652       NAME    'string'   0.963602
# 1725       NAME         'a'   0.908046
# 2599       NAME     'event'   0.858238
# 997        NAME   '_amount'   0.852490
# 4725       NAME     'throw'   0.842912
# 1946       NAME         'b'   0.816092
# 5484         OP         '|'   0.772031

# %%
# NOTE: better dump to json!!
token_freq_200.to_csv(os.path.join(out_path, 'token_freq_200.csv'))

# %%
token_freq_200[token_freq_200['value'].apply(lambda x: bool(re.match("'\\\\n'", x)))]
# Out:
#      type value        num
# 5120   NL  '\n'  67.452107

# %%
token_freq_200.filter(like="'true'", axis=0)
# Out:
# Empty DataFrame
# Columns: [type, value, num]
# Index: []

# %%
 token_freq_200['value'].values
# Out:
# array(["'\\n'", "'('", "')'", "';'", "','", "'.'", "'{'", "'}'", "'='",
#        "'function'", "'address'", "'['", "']'", "'public'", "'uint'",
#        "'uint256'", "'returns'", "'return'", "'0'", "'if'", "'msg'",
#        "'sender'", "'i'", "'bool'", "'require'", "'import'", "'+'", "'=='",
#        "'constant'", "'internal'", "'db'", "'>'", "'&'", "'bytes32'",
#        "'true'", "'value'", "'contract'", "'_value'", "'<'", "''",
#        "'length'", "'owner'", "'1'", "'string'", "'a'", "'event'",
#        "'_amount'", "'throw'", "'b'", "'|'", "'!='", "'_to'", "'for'",
#        "'is'", "'indexed'", "'balances'", "'amount'", "'transactionId'",
#        "'add'", "'_from'", "'view'", "'>='", "'-'", "'onlyOwner'",
#        "'uint8'", "'*'", "'/'", "':'", "'modifier'", "'_'", "'token'",
#        "'_owner'", "'bytes'", "'!'", "'false'", "'else'", "'this'",
#        "'jobId'", "'totalSupply'", "'sha3'", "'_spender'", "'now'",
#        "'EthlanceDB'", "'mapping'", "'transfer'", "'args'", "'_market'",
#        "'new'", "'sub'", "'<='", "'dynargs'", "'c'", "'external'",
#        "'owners'", "'userId'", "'memory'", "'count'", "'controller'",
#        "'var'", "'2'", "'mul'", "'contractId'", "'private'", "'_data'",
#        "'+='", "'result'", "'_outcome'", "'allowed'", "'balance'",
#        "'_orderId'", "'balanceOf'", "'payable'", "'int'", "'j'", "'div'",
#        "'success'", "'market'", "'self'", "'SafeMath'", "'datasource'",
#        "' '", "'_universe'", "'0x0'", "'IMarket'", "'using'", "'tokens'",
#        "'_token'", "'safeAdd'", "'Order'", "'to'", "'3'", "'id'",
#        "'startTime'", "'the'", "'transferFrom'", "'assert'", "'executed'",
#        "'State'", "'from'", "'newOwner'", "'Migrations'", "'IUniverse'",
#        "'100'", "'weiRaised'", "'Ownable'", "'beneficiary'",
#        "'oraclize_query'", "'Transfer'", "'ether'", "'investor'",
#        "'_price'", "'key'", "'pure'", "'price'", "'_startTime'",
#        "'_sender'", "'data'", "'ethlanceDB'", "'state'", "'10'",
#        "'destination'", "'_target'", "'_endTime'", "'_len'", "'super'",
#        "'ONE'", "'_orderData'", "'name'", "'SharedLibrary'", "'_required'",
#        "'block'", "'Types'", "'isOwner'", "'addr'", "'onlyInGoodTimes'",
#        "'timestamp'", "'_order'", "'_beneficiary'", "'gaslimit'",
#        "'endTime'", "'mint'", "'transactions'", "'checkpoints'",
#        "'weiAmount'", "'4'", "'creator'", "'universe'", "'eventContract'",
#        "'_betterOrderId'", "'_type'", "'32'", "'tx'", "'array'",
#        "'_worseOrderId'", "'len'", "'rate'", "'uint64'", "'IFeeWindow'",
#        "'x'", "'ptr'"], dtype=object)
